# %% [markdown]
# ## Despliegue del modelo de prediccion de Diabetes
# --------------------------

# %% [markdown]
# Se hace el despliegue del mejor modelo de predicción encontrado, que en este caso se trata de un modelo de random forest. El cual sera cargado para ser utilizado por una api mediante MLflow y poder obtener prediciones.

# %% [markdown]
# ## **Librerias**

# %%
import numpy as np
import pandas as pd
import joblib
import mlflow
import os
import requests
import mlflow.pyfunc
import re
np.random.seed(3)

# %% [markdown]
# ## Funciones
#
# -----------------------------
#
# A continuacion se muestran unas funciones necesarias para el preprocesamiento de los datos de entrada y carga del modelo final.

# %%
def prep(x,columns):
    X = pd.DataFrame(x, columns=columns)
    bol = ['hypertension', 'heart_disease']
    num = ['age', 'bmi', 'HbA1c_level', 'blood_glucose_level']
    cat = ['gender', 'smoking_history']
    X_bol = X[bol].values
    X_num = X[num].values
    X_cat = X[cat].values
    min_max = joblib.load('/home/kevo/Escritorio/mlds6/tdsp_template_grupo8/scripts/preprocessing/min_max_scaler.pkl')
    one_h = joblib.load('/home/kevo/Escritorio/mlds6/tdsp_template_grupo8/scripts/preprocessing/one_hencoder.pkl')
    X_num_minmax = min_max.transform(X_num)
    X_cat_onehot = one_h.transform(X_cat)
    X_fin = np.concatenate((X_num_minmax, X_bol ,X_cat_onehot),axis=1) 
    return X_fin.tolist()

# %%
def modelo():
    modelo = joblib.load('/home/kevo/Escritorio/proyectos/despliegue/proyec/RF_model.joblib')
    return modelo

# %% [markdown]
# Antes de desplegar el modelo, se configura todo el entorno de ML flow, primero se lanza un servidor web.

# %%
command = """
mlflow server \
        --backend-store-uri sqlite:///tracking.db \
        --default-artifact-root file:mlruns \
        -p 5000 &
"""
get_ipython().system_raw(command)
# Out:
# /home/kevo/.local/lib/python3.10/site-packages/pydantic/_internal/_config.py:334: UserWarning: Valid config keys have changed in V2:
# * 'schema_extra' has been renamed to 'json_schema_extra'
#   warnings.warn(message, UserWarning)
# 2024/06/04 19:02:26 INFO mlflow.store.db.utils: Creating initial MLflow database tables...
# 2024/06/04 19:02:26 INFO mlflow.store.db.utils: Updating database tables
# INFO  [alembic.runtime.migration] Context impl SQLiteImpl.
# INFO  [alembic.runtime.migration] Will assume non-transactional DDL.
# INFO  [alembic.runtime.migration] Running upgrade  -> 451aebb31d03, add metric step
# INFO  [alembic.runtime.migration] Running upgrade 451aebb31d03 -> 90e64c465722, migrate user column to tags
# INFO  [alembic.runtime.migration] Running upgrade 90e64c465722 -> 181f10493468, allow nulls for metric values
# INFO  [alembic.runtime.migration] Running upgrade 181f10493468 -> df50e92ffc5e, Add Experiment Tags Table
# INFO  [alembic.runtime.migration] Running upgrade df50e92ffc5e -> 7ac759974ad8, Update run tags with larger limit
# INFO  [alembic.runtime.migration] Running upgrade 7ac759974ad8 -> 89d4b8295536, create latest metrics table
# INFO  [89d4b8295536_create_latest_metrics_table_py] Migration complete!
# INFO  [alembic.runtime.migration] Running upgrade 89d4b8295536 -> 2b4d017a5e9b, add model registry tables to db
# INFO  [2b4d017a5e9b_add_model_registry_tables_to_db_py] Adding registered_models and model_versions tables to database.
# INFO  [2b4d017a5e9b_add_model_registry_tables_to_db_py] Migration complete!
# INFO  [alembic.runtime.migration] Running upgrade 2b4d017a5e9b -> cfd24bdc0731, Update run status constraint with killed
# INFO  [alembic.runtime.migration] Running upgrade cfd24bdc0731 -> 0a8213491aaa, drop_duplicate_killed_constraint
# INFO  [alembic.runtime.migration] Running upgrade 0a8213491aaa -> 728d730b5ebd, add registered model tags table
# INFO  [alembic.runtime.migration] Running upgrade 728d730b5ebd -> 27a6a02d2cf1, add model version tags table
# INFO  [alembic.runtime.migration] Running upgrade 27a6a02d2cf1 -> 84291f40a231, add run_link to model_version
# INFO  [alembic.runtime.migration] Running upgrade 84291f40a231 -> a8c4a736bde6, allow nulls for run_id
# INFO  [alembic.runtime.migration] Running upgrade a8c4a736bde6 -> 39d1c3be5f05, add_is_nan_constraint_for_metrics_tables_if_necessary
# INFO  [alembic.runtime.migration] Running upgrade 39d1c3be5f05 -> c48cb773bb87, reset_default_value_for_is_nan_in_metrics_table_for_mysql
# INFO  [alembic.runtime.migration] Running upgrade c48cb773bb87 -> bd07f7e963c5, create index on run_uuid
# INFO  [alembic.runtime.migration] Running upgrade bd07f7e963c5 -> 0c779009ac13, add deleted_time field to runs table
# INFO  [alembic.runtime.migration] Running upgrade 0c779009ac13 -> cc1f77228345, change param value length to 500
# INFO  [alembic.runtime.migration] Running upgrade cc1f77228345 -> 97727af70f4d, Add creation_time and last_update_time to experiments table
# INFO  [alembic.runtime.migration] Running upgrade 97727af70f4d -> 3500859a5d39, Add Model Aliases table
# INFO  [alembic.runtime.migration] Running upgrade 3500859a5d39 -> 7f2a7d5fae7d, add datasets inputs input_tags tables
# INFO  [alembic.runtime.migration] Running upgrade 7f2a7d5fae7d -> 2d6e25af4d3e, increase max param val length from 500 to 8000
# INFO  [alembic.runtime.migration] Running upgrade 2d6e25af4d3e -> acf3f17fdcc7, add storage location field to model versions
# INFO  [alembic.runtime.migration] Running upgrade acf3f17fdcc7 -> 867495a8f9d4, add trace tables
# INFO  [alembic.runtime.migration] Running upgrade 867495a8f9d4 -> 5b0e9adcef9c, add cascade deletion to trace tables foreign keys
# INFO  [alembic.runtime.migration] Context impl SQLiteImpl.
# INFO  [alembic.runtime.migration] Will assume non-transactional DDL.
# [2024-06-04 19:02:32 -0500] [28566] [INFO] Starting gunicorn 22.0.0
# [2024-06-04 19:02:32 -0500] [28566] [INFO] Listening at: http://127.0.0.1:5000 (28566)
# [2024-06-04 19:02:32 -0500] [28566] [INFO] Using worker: sync
# [2024-06-04 19:02:32 -0500] [28567] [INFO] Booting worker with pid: 28567
# [2024-06-04 19:02:32 -0500] [28568] [INFO] Booting worker with pid: 28568
# [2024-06-04 19:02:32 -0500] [28569] [INFO] Booting worker with pid: 28569
# [2024-06-04 19:02:32 -0500] [28570] [INFO] Booting worker with pid: 28570

# %% [markdown]
# se define el servidor que MLflow estará manejando que en nuestro caso se trata de un servidor local

# %%
mlflow.set_tracking_uri("http://localhost:5000")

# %% [markdown]
# Se crea un experimento de MLflow

# %%
exp_id = mlflow.create_experiment(name="diabetes", artifact_location="mlruns/")

# %% [markdown]
# y corremos el modelo en MLflow para que genere el archivo .pkl que es el se utilizara para generar las predicciones del despliegue

# %%
with mlflow.start_run(
        run_name="random_forest", experiment_id=exp_id
        ):
    model = modelo()
    mlflow.sklearn.log_model(model, "model")

# %% [markdown]
# se especifica la url del servidor de seguimiento de ml flow

# %%
os.environ["MLFLOW_TRACKING_URI"] = "http://localhost:5000"

# %% [markdown]
# se lanza el api de MLflow

# %%
command = """
mlflow models serve -m 'models:/diabetes/1' -p 8001 --env-manager 'local' &
"""
get_ipython().system_raw(command)
# Out:
# /home/kevo/.local/lib/python3.10/site-packages/pydantic/_internal/_config.py:334: UserWarning: Valid config keys have changed in V2:
# * 'schema_extra' has been renamed to 'json_schema_extra'
#   warnings.warn(message, UserWarning)
# Downloading artifacts: 100%|██████████| 9/9 [00:00<00:00, 5570.95it/s]
# 2024/06/04 19:04:46 INFO mlflow.models.flavor_backend_registry: Selected backend for flavor 'python_function'
# 2024/06/04 19:04:46 INFO mlflow.pyfunc.backend: === Running command 'exec gunicorn --timeout=60 -b 127.0.0.1:8001 -w 1 ${GUNICORN_CMD_ARGS} -- mlflow.pyfunc.scoring_server.wsgi:app'
# [2024-06-04 19:04:46 -0500] [28841] [INFO] Starting gunicorn 22.0.0
# [2024-06-04 19:04:46 -0500] [28841] [INFO] Listening at: http://127.0.0.1:8001 (28841)
# [2024-06-04 19:04:46 -0500] [28841] [INFO] Using worker: sync
# [2024-06-04 19:04:46 -0500] [28842] [INFO] Booting worker with pid: 28842

# %% [markdown]
# ## Sistema de predicción de diabetes.
# ------------------
# En esta sección se cargan los datos a introducir en el modelo de pronostico. Como primer paso se debe digitar la dirección donde se encuentra el archivo csv con los registros que ingresaran al modelo. A continuación, se ingresa la cantidad de registros a cargar y finalmente se puede ver una parte de ellos.

# %%
print('¡Hola! Bienvenido al sistema de detección de diabetes.\n')
dir = str(input("Ingresa una tabla de datos en formato csv: \n"))
df = pd.read_csv(dir)
n_registros = int(input("¿Cuantos registros quieres cargar?: \n"))
df = df[:n_registros]
columnas = df.columns
print('Revisa algunos de los registros cargados')
df.head(10)
# Out:
# ¡Hola! Bienvenido al sistema de detección de diabetes.
#
# Revisa algunos de los registros cargados
#    gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0  Female  51.0             0              0         current  36.77
# 1    Male  12.0             0              0         No Info  22.29
# 2  Female  60.0             1              0          former  34.24
# 3    Male  80.0             0              0          former  24.39
# 4    Male  80.0             0              1         No Info  35.00
# 5  Female  16.0             0              0           never  19.69
# 6    Male  78.0             1              0           never  22.14
# 7    Male  78.0             0              0         No Info  35.49
# 8  Female  49.0             0              0           never  31.28
# 9  Female  16.0             0              0           never  24.55
#
#    HbA1c_level  blood_glucose_level
# 0          6.6                  159
# 1          4.5                   90
# 2          6.2                   90
# 3          4.0                  100
# 4          4.5                  145
# 5          4.0                  126
# 6          3.5                   80
# 7          4.5                  155
# 8          6.2                  145
# 9          5.0                  155

# %% [markdown]
# Se realiza el preprocesamiento de los registros cargados

# %%
df = df.values.tolist()
data = prep(df,columnas)

# %% [markdown]
# Y se hace un post con los datos preprocesados para que ingresen al servidor de MLflow, ejecuten el modelo de predicción y se obtengan los resultados correspondientes.

# %%
r = requests.post("http://localhost:8001/invocations", json={"inputs": data})
predictions = re.findall(r'\d+', r.text)
predictions = list(map(int, predictions))
for i in range(len(predictions)):
    print(f"Paciente {i+1}: {'No diabetes' if predictions[i]==0 else 'Diabetes'}")
# Out:
# Paciente 1: No diabetes
# Paciente 2: No diabetes
# Paciente 3: No diabetes
# Paciente 4: No diabetes
# Paciente 5: No diabetes
# Paciente 6: No diabetes
# Paciente 7: No diabetes
# Paciente 8: No diabetes
# Paciente 9: No diabetes
# Paciente 10: No diabetes
# Paciente 11: No diabetes
# Paciente 12: No diabetes
# Paciente 13: No diabetes
# Paciente 14: No diabetes
# Paciente 15: No diabetes
# Paciente 16: No diabetes
# Paciente 17: Diabetes
# Paciente 18: No diabetes
# Paciente 19: No diabetes
# Paciente 20: No diabetes
# Paciente 21: No diabetes
# Paciente 22: No diabetes
# Paciente 23: No diabetes
# Paciente 24: No diabetes
# Paciente 25: No diabetes
# Paciente 26: No diabetes
# Paciente 27: No diabetes
# Paciente 28: No diabetes
# Paciente 29: No diabetes
# Paciente 30: No diabetes
# Paciente 31: No diabetes
# Paciente 32: No diabetes
# Paciente 33: No diabetes
# Paciente 34: No diabetes
# Paciente 35: No diabetes
# Paciente 36: No diabetes
# Paciente 37: No diabetes
# Paciente 38: No diabetes
# Paciente 39: No diabetes
# Paciente 40: No diabetes
# Paciente 41: No diabetes
# Paciente 42: No diabetes
# Paciente 43: No diabetes
# Paciente 44: No diabetes
# Paciente 45: No diabetes
# Paciente 46: No diabetes
# Paciente 47: No diabetes
# Paciente 48: No diabetes
# Paciente 49: No diabetes
# Paciente 50: No diabetes
# Paciente 51: No diabetes
# Paciente 52: No diabetes
# Paciente 53: No diabetes
# Paciente 54: No diabetes
# Paciente 55: No diabetes
# Paciente 56: No diabetes
# Paciente 57: No diabetes
# Paciente 58: No diabetes
# Paciente 59: No diabetes
# Paciente 60: No diabetes
# Paciente 61: No diabetes
# Paciente 62: No diabetes
# Paciente 63: No diabetes
# Paciente 64: No diabetes
# Paciente 65: No diabetes
# Paciente 66: No diabetes
# Paciente 67: No diabetes
# Paciente 68: No diabetes
# Paciente 69: No diabetes
# Paciente 70: No diabetes
# Paciente 71: No diabetes
# Paciente 72: No diabetes
# Paciente 73: No diabetes
# Paciente 74: No diabetes
# Paciente 75: No diabetes
# Paciente 76: No diabetes
# Paciente 77: No diabetes
# Paciente 78: No diabetes
# Paciente 79: No diabetes
# Paciente 80: No diabetes
# Paciente 81: No diabetes
# Paciente 82: No diabetes
# Paciente 83: No diabetes
# Paciente 84: No diabetes
# Paciente 85: No diabetes
# Paciente 86: No diabetes
# Paciente 87: Diabetes
# Paciente 88: No diabetes
# Paciente 89: No diabetes
# Paciente 90: No diabetes
# Paciente 91: No diabetes
# Paciente 92: No diabetes
# Paciente 93: No diabetes
# Paciente 94: No diabetes
# Paciente 95: No diabetes
# Paciente 96: No diabetes
# Paciente 97: No diabetes
# Paciente 98: Diabetes
# Paciente 99: No diabetes
# Paciente 100: No diabetes
# Paciente 101: No diabetes
# Paciente 102: No diabetes
# Paciente 103: No diabetes
# Paciente 104: No diabetes
# Paciente 105: No diabetes
# Paciente 106: No diabetes
# Paciente 107: No diabetes
# Paciente 108: No diabetes
# Paciente 109: No diabetes
# Paciente 110: Diabetes
# Paciente 111: No diabetes
# Paciente 112: No diabetes
# Paciente 113: No diabetes
# Paciente 114: No diabetes
# Paciente 115: No diabetes
# Paciente 116: No diabetes
# Paciente 117: No diabetes
# Paciente 118: No diabetes
# Paciente 119: No diabetes
# Paciente 120: No diabetes
# Paciente 121: No diabetes
# Paciente 122: Diabetes
# Paciente 123: No diabetes
# Paciente 124: No diabetes
# Paciente 125: No diabetes
# Paciente 126: No diabetes
# Paciente 127: Diabetes
# Paciente 128: No diabetes
# Paciente 129: No diabetes
# Paciente 130: No diabetes
# Paciente 131: No diabetes
# Paciente 132: No diabetes
# Paciente 133: No diabetes
# Paciente 134: No diabetes
# Paciente 135: No diabetes
# Paciente 136: No diabetes
# Paciente 137: No diabetes
# Paciente 138: No diabetes
# Paciente 139: No diabetes
# Paciente 140: No diabetes
# Paciente 141: No diabetes
# Paciente 142: No diabetes
# Paciente 143: No diabetes
# Paciente 144: No diabetes
# Paciente 145: No diabetes
# Paciente 146: No diabetes
# Paciente 147: No diabetes
# Paciente 148: No diabetes
# Paciente 149: No diabetes
# Paciente 150: Diabetes
# Paciente 151: No diabetes
# Paciente 152: No diabetes
# Paciente 153: No diabetes
# Paciente 154: No diabetes
# Paciente 155: No diabetes
# Paciente 156: No diabetes
# Paciente 157: No diabetes
# Paciente 158: No diabetes
# Paciente 159: No diabetes
# Paciente 160: No diabetes
# Paciente 161: No diabetes
# Paciente 162: No diabetes
# Paciente 163: No diabetes
# Paciente 164: No diabetes
# Paciente 165: No diabetes
# Paciente 166: No diabetes
# Paciente 167: No diabetes
# Paciente 168: No diabetes
# Paciente 169: No diabetes
# Paciente 170: No diabetes
# Paciente 171: No diabetes
# Paciente 172: No diabetes
# Paciente 173: No diabetes
# Paciente 174: No diabetes
# Paciente 175: No diabetes
# Paciente 176: No diabetes
# Paciente 177: No diabetes
# Paciente 178: No diabetes
# Paciente 179: No diabetes
# Paciente 180: No diabetes
# Paciente 181: No diabetes
# Paciente 182: No diabetes
# Paciente 183: No diabetes
# Paciente 184: No diabetes
# Paciente 185: No diabetes
# Paciente 186: No diabetes
# Paciente 187: Diabetes
# Paciente 188: No diabetes
# Paciente 189: No diabetes
# Paciente 190: No diabetes
# Paciente 191: Diabetes
# Paciente 192: No diabetes
# Paciente 193: No diabetes
# Paciente 194: No diabetes
# Paciente 195: No diabetes
# Paciente 196: No diabetes
# Paciente 197: No diabetes
# Paciente 198: No diabetes
# Paciente 199: No diabetes
# Paciente 200: No diabetes
# Paciente 201: No diabetes
# Paciente 202: No diabetes
# Paciente 203: No diabetes
# Paciente 204: No diabetes
# Paciente 205: No diabetes
# Paciente 206: No diabetes
# Paciente 207: No diabetes
# Paciente 208: No diabetes
# Paciente 209: No diabetes
# Paciente 210: No diabetes
# Paciente 211: No diabetes
# Paciente 212: No diabetes
# Paciente 213: No diabetes
# Paciente 214: No diabetes
# Paciente 215: Diabetes
# Paciente 216: No diabetes
# Paciente 217: No diabetes
# Paciente 218: No diabetes
# Paciente 219: No diabetes
# Paciente 220: No diabetes
# Paciente 221: No diabetes
# Paciente 222: No diabetes
# Paciente 223: No diabetes
# Paciente 224: No diabetes
# Paciente 225: No diabetes
# Paciente 226: No diabetes
# Paciente 227: No diabetes
# Paciente 228: No diabetes
# Paciente 229: Diabetes
# Paciente 230: No diabetes
# Paciente 231: No diabetes
# Paciente 232: No diabetes
# Paciente 233: No diabetes
# Paciente 234: No diabetes
# Paciente 235: No diabetes
# Paciente 236: No diabetes
# Paciente 237: No diabetes
# Paciente 238: No diabetes
# Paciente 239: No diabetes
# Paciente 240: No diabetes
# Paciente 241: No diabetes
# Paciente 242: No diabetes
# Paciente 243: No diabetes
# Paciente 244: No diabetes
# Paciente 245: No diabetes
# Paciente 246: No diabetes
# Paciente 247: No diabetes
# Paciente 248: No diabetes
# Paciente 249: No diabetes
# Paciente 250: No diabetes
# Paciente 251: No diabetes
# Paciente 252: No diabetes
# Paciente 253: No diabetes
# Paciente 254: No diabetes
# Paciente 255: No diabetes
# Paciente 256: No diabetes
# Paciente 257: No diabetes
# Paciente 258: No diabetes
# Paciente 259: No diabetes
# Paciente 260: No diabetes
# Paciente 261: No diabetes
# Paciente 262: No diabetes
# Paciente 263: No diabetes
# Paciente 264: No diabetes
# Paciente 265: No diabetes
# Paciente 266: No diabetes
# Paciente 267: No diabetes
# Paciente 268: No diabetes
# Paciente 269: No diabetes
# Paciente 270: No diabetes
# Paciente 271: Diabetes
# Paciente 272: Diabetes
# Paciente 273: No diabetes
# Paciente 274: No diabetes
# Paciente 275: No diabetes
# Paciente 276: No diabetes
# Paciente 277: No diabetes
# Paciente 278: Diabetes
# Paciente 279: No diabetes
# Paciente 280: No diabetes
# Paciente 281: No diabetes
# Paciente 282: No diabetes
# Paciente 283: No diabetes
# Paciente 284: No diabetes
# Paciente 285: No diabetes
# Paciente 286: No diabetes
# Paciente 287: No diabetes
# Paciente 288: No diabetes
# Paciente 289: No diabetes
# Paciente 290: Diabetes
# Paciente 291: No diabetes
# Paciente 292: No diabetes
# Paciente 293: No diabetes
# Paciente 294: Diabetes
# Paciente 295: No diabetes
# Paciente 296: Diabetes
# Paciente 297: No diabetes
# Paciente 298: No diabetes
# Paciente 299: No diabetes
# Paciente 300: No diabetes
# Paciente 301: No diabetes
# Paciente 302: No diabetes
# Paciente 303: No diabetes
# Paciente 304: Diabetes
# Paciente 305: No diabetes
# Paciente 306: No diabetes
# Paciente 307: No diabetes
# Paciente 308: No diabetes
# Paciente 309: Diabetes
# Paciente 310: Diabetes
# Paciente 311: No diabetes
# Paciente 312: No diabetes
# Paciente 313: No diabetes
# Paciente 314: No diabetes
# Paciente 315: No diabetes
# Paciente 316: No diabetes
# Paciente 317: No diabetes
# Paciente 318: No diabetes
# Paciente 319: No diabetes
# Paciente 320: No diabetes
# Paciente 321: No diabetes
# Paciente 322: No diabetes
# Paciente 323: No diabetes
# Paciente 324: No diabetes
# Paciente 325: No diabetes
# Paciente 326: No diabetes
# Paciente 327: No diabetes
# Paciente 328: No diabetes
# Paciente 329: No diabetes
# Paciente 330: No diabetes
# Paciente 331: No diabetes
# Paciente 332: No diabetes
# Paciente 333: No diabetes
# Paciente 334: No diabetes
# Paciente 335: No diabetes
# Paciente 336: No diabetes
# Paciente 337: No diabetes
# Paciente 338: No diabetes
# Paciente 339: No diabetes
# Paciente 340: No diabetes
# Paciente 341: No diabetes
# Paciente 342: No diabetes
# Paciente 343: No diabetes
# Paciente 344: No diabetes
# Paciente 345: No diabetes
# Paciente 346: No diabetes
# Paciente 347: Diabetes
# Paciente 348: No diabetes
# Paciente 349: No diabetes
# Paciente 350: No diabetes
# Paciente 351: No diabetes
# Paciente 352: No diabetes
# Paciente 353: No diabetes
# Paciente 354: No diabetes
# Paciente 355: No diabetes
# Paciente 356: No diabetes
# Paciente 357: No diabetes
# Paciente 358: No diabetes
# Paciente 359: No diabetes
# Paciente 360: No diabetes
# Paciente 361: No diabetes
# Paciente 362: No diabetes
# Paciente 363: No diabetes
# Paciente 364: No diabetes
# Paciente 365: No diabetes
# Paciente 366: Diabetes
# Paciente 367: No diabetes
# Paciente 368: No diabetes
# Paciente 369: No diabetes
# Paciente 370: No diabetes
# Paciente 371: No diabetes
# Paciente 372: No diabetes
# Paciente 373: Diabetes
# Paciente 374: No diabetes
# Paciente 375: No diabetes
# Paciente 376: No diabetes
# Paciente 377: No diabetes
# Paciente 378: No diabetes
# Paciente 379: No diabetes
# Paciente 380: No diabetes
# Paciente 381: No diabetes
# Paciente 382: No diabetes
# Paciente 383: No diabetes
# Paciente 384: No diabetes
# Paciente 385: No diabetes
# Paciente 386: No diabetes
# Paciente 387: Diabetes
# Paciente 388: Diabetes
# Paciente 389: No diabetes
# Paciente 390: No diabetes
# Paciente 391: No diabetes
# Paciente 392: No diabetes
# Paciente 393: No diabetes
# Paciente 394: No diabetes
# Paciente 395: No diabetes
# Paciente 396: No diabetes
# Paciente 397: No diabetes
# Paciente 398: No diabetes
# Paciente 399: No diabetes
# Paciente 400: No diabetes
# Paciente 401: No diabetes
# Paciente 402: No diabetes
# Paciente 403: No diabetes
# Paciente 404: No diabetes
# Paciente 405: No diabetes
# Paciente 406: No diabetes
# Paciente 407: No diabetes
# Paciente 408: No diabetes
# Paciente 409: No diabetes
# Paciente 410: No diabetes
# Paciente 411: No diabetes
# Paciente 412: No diabetes
# Paciente 413: No diabetes
# Paciente 414: No diabetes
# Paciente 415: No diabetes
# Paciente 416: No diabetes
# Paciente 417: No diabetes
# Paciente 418: No diabetes
# Paciente 419: No diabetes
# Paciente 420: No diabetes
# Paciente 421: No diabetes
# Paciente 422: No diabetes
# Paciente 423: No diabetes
# Paciente 424: No diabetes
# Paciente 425: No diabetes
# Paciente 426: No diabetes
# Paciente 427: No diabetes
# Paciente 428: No diabetes
# Paciente 429: No diabetes
# Paciente 430: No diabetes
# Paciente 431: No diabetes
# Paciente 432: No diabetes
# Paciente 433: No diabetes
# Paciente 434: No diabetes
# Paciente 435: No diabetes
# Paciente 436: No diabetes
# Paciente 437: No diabetes
# Paciente 438: No diabetes
# Paciente 439: No diabetes
# Paciente 440: No diabetes
# Paciente 441: No diabetes
# Paciente 442: No diabetes
# Paciente 443: No diabetes
# Paciente 444: No diabetes
# Paciente 445: No diabetes
# Paciente 446: No diabetes
# Paciente 447: No diabetes
# Paciente 448: No diabetes
# Paciente 449: No diabetes
# Paciente 450: No diabetes
# Paciente 451: No diabetes
# Paciente 452: No diabetes
# Paciente 453: No diabetes
# Paciente 454: No diabetes
# Paciente 455: No diabetes
# Paciente 456: No diabetes
# Paciente 457: No diabetes
# Paciente 458: No diabetes
# Paciente 459: No diabetes
# Paciente 460: Diabetes
# Paciente 461: No diabetes
# Paciente 462: No diabetes
# Paciente 463: No diabetes
# Paciente 464: No diabetes
# Paciente 465: No diabetes
# Paciente 466: No diabetes
# Paciente 467: No diabetes
# Paciente 468: No diabetes
# Paciente 469: No diabetes
# Paciente 470: No diabetes
# Paciente 471: No diabetes
# Paciente 472: No diabetes
# Paciente 473: No diabetes
# Paciente 474: No diabetes
# Paciente 475: No diabetes
# Paciente 476: No diabetes
# Paciente 477: No diabetes
# Paciente 478: No diabetes
# Paciente 479: No diabetes
# Paciente 480: No diabetes
# Paciente 481: No diabetes
# Paciente 482: No diabetes
# Paciente 483: No diabetes
# Paciente 484: No diabetes
# Paciente 485: No diabetes
# Paciente 486: No diabetes
# Paciente 487: No diabetes
# Paciente 488: No diabetes
# Paciente 489: No diabetes
# Paciente 490: Diabetes
# Paciente 491: No diabetes
# Paciente 492: No diabetes
# Paciente 493: No diabetes
# Paciente 494: No diabetes
# Paciente 495: No diabetes
# Paciente 496: No diabetes
# Paciente 497: No diabetes
# Paciente 498: No diabetes
# Paciente 499: No diabetes
# Paciente 500: No diabetes
